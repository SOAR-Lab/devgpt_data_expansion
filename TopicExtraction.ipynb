# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import json
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel
import numpy as np
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/sp3856/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sp3856/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_comments(comments):
    stop_words = set(stopwords.words('english'))
    cleaned_comments = []
    for comment in comments:
        comment = BeautifulSoup(comment, "html.parser").get_text()
        comment = re.sub(r"[^a-zA-Z\s]", "", comment)
        tokens = word_tokenize(comment.lower())
        tokens = [word for word in tokens if word not in stop_words and len(word) > 1]
        cleaned_comments.append(tokens)
    #print(f"Cleaned Comments: {cleaned_comments}")
    return cleaned_comments

def get_comment_topics(lda_model, corpus, n_topics=2):
    comment_topics = []
    for i, row in enumerate(corpus):
        topics = sorted(lda_model.get_document_topics(row), key=lambda x: -x[1])[:n_topics]
        comment_topics.append(topics)
        #print(f"Comment {i + 1}: {topics}")
    return comment_topics

def get_top_topics_overall(comment_topics, num_topics=2):
    if not comment_topics or len(comment_topics[0]) < num_topics:
        return list(range(len(comment_topics[0])))
    
    num_total_topics = len(comment_topics[0])  
    topic_scores = np.zeros(num_total_topics)

    for topics in comment_topics:
        for topic, prob in topics:
            topic_scores[topic] += prob

    top_topics_indices = np.argsort(topic_scores)[-num_topics:][::-1]
    return top_topics_indices

def clean_topic_keywords(topics, top_topic_indices):
    readable_topics = []
    for idx in top_topic_indices:
        topic_id, topic_desc = topics[idx]
        keywords = [kw.split('*')[1].strip('"') for kw in topic_desc.split(' + ')]
        print(f"Topic {topic_id + 1}: {', '.join(keywords)}")
        readable_topics.append((topic_id, keywords))
    return readable_topics

input_json_file = 'hacker_news_comments_chat_openai.json'
output_csv_file = 'hacker_news_with_chatopenai_topics.csv'

with open(input_json_file, mode='r', encoding='utf8') as infile:
    data = json.load(infile)

with open(output_csv_file, mode='w', newline='', encoding='utf8') as csvfile:
    fieldnames = ["Hacker News URL", "Top Topics"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for entry in data:
        comments = entry.get("Comments", [])
        if comments:
            print(f"Processing URL: {entry['Hacker News URL']} with {len(comments)} comments.")
            
            cleaned_comments = preprocess_comments(comments)
            dictionary = Dictionary(cleaned_comments)
            #print(f"Number of unique tokens in dictionary: {len(dictionary)}")
            #print(f"Sample dictionary tokens: {list(dictionary.items())}")
            
            corpus = [dictionary.doc2bow(comment) for comment in cleaned_comments]
            #print(f"Corpus sample: {corpus}")

            if len(dictionary) > 0:
                lda_model = LdaModel(corpus, num_topics=2, id2word=dictionary, passes=10)
                topics = lda_model.print_topics(num_words=5)
                for idx, topic in topics:
                    print(f"Topic {idx}: {topic}")

                comment_topics = get_comment_topics(lda_model, corpus)
                if comment_topics and len(comment_topics[0]) > 0:
                    top_topics_indices = get_top_topics_overall(comment_topics, num_topics=2)
                    readable_topics = clean_topic_keywords(topics, top_topics_indices)

                    topics_str = "; ".join([f"Topic {topic_id + 1}: {', '.join(keywords)}" for topic_id, keywords in readable_topics])
                    entry["Top Topics"] = topics_str
                    print(f"Top Topics for {entry['Hacker News URL']}: {topics_str}")
                else:
                    entry["Top Topics"] = "Insufficient data for topics"
            else:
                entry["Top Topics"] = "No topics found"
        else:
            print(f"No comments available for URL: {entry['Hacker News URL']}")
            entry["Top Topics"] = "No comments available"

        writer.writerow({
            "Hacker News URL": entry["Hacker News URL"],
            "Top Topics": entry.get("Top Topics", "No topics available")
        })

print(f"Output written to {output_csv_file}")
# Out:
# Processing URL: https://news.ycombinator.com/item?id=37195889 with 1 comments.
# Topic 0: 0.020*"chatgpt" + 0.020*"example" + 0.016*"use" + 0.016*"results" + 0.016*"google"
# Topic 1: 0.008*"example" + 0.008*"chatgpt" + 0.008*"like" + 0.008*"google" + 0.008*"results"
# Topic 1: chatgpt, example, use, results, google
# Top Topics for https://news.ycombinator.com/item?id=37195889: Topic 1: chatgpt, example, use, results, google
# No comments available for URL: https://news.ycombinator.com/item?id=37183231
# No comments available for URL: https://news.ycombinator.com/item?id=37178810
# Processing URL: https://news.ycombinator.com/item?id=37129724 with 5 comments.
# Topic 0: 0.052*"plugin" + 0.052*"code" + 0.052*"ask" + 0.031*"repo" + 0.031*"one"
# Topic 1: 0.058*"github" + 0.045*"code" + 0.045*"questions" + 0.032*"repo" + 0.032*"plugin"
# Topic 2: github, code, questions, repo, plugin
# Topic 1: plugin, code, ask, repo, one
# Top Topics for https://news.ycombinator.com/item?id=37129724: Topic 2: github, code, questions, repo, plugin; Topic 1: plugin, code, ask, repo, one
# Processing URL: https://news.ycombinator.com/item?id=37167185 with 6 comments.
# Topic 0: 0.041*"joke" + 0.015*"llm" + 0.011*"bias" + 0.011*"one" + 0.011*"political"
# Topic 1: 0.030*"political" + 0.023*"bias" + 0.016*"neutral" + 0.016*"biased" + 0.016*"definition"
# Topic 2: political, bias, neutral, biased, definition
# Topic 1: joke, llm, bias, one, political
# Top Topics for https://news.ycombinator.com/item?id=37167185: Topic 2: political, bias, neutral, biased, definition; Topic 1: joke, llm, bias, one, political
# Processing URL: https://news.ycombinator.com/item?id=37140831 with 40 comments.
# Topic 0: 0.012*"data" + 0.012*"ai" + 0.010*"like" + 0.009*"people" + 0.009*"hard"
# Topic 1: 0.009*"llms" + 0.008*"rice" + 0.006*"machine" + 0.006*"agricultural" + 0.006*"new"
# Topic 1: data, ai, like, people, hard
# Topic 2: llms, rice, machine, agricultural, new
# Top Topics for https://news.ycombinator.com/item?id=37140831: Topic 1: data, ai, like, people, hard; Topic 2: llms, rice, machine, agricultural, new
# Processing URL: https://news.ycombinator.com/item?id=37159680 with 39 comments.
# Topic 0: 0.016*"km" + 0.014*"would" + 0.012*"asteroid" + 0.010*"diameter" + 0.009*"impact"
# Topic 1: 0.016*"atmosphere" + 0.016*"would" + 0.013*"much" + 0.011*"like" + 0.009*"get"
# Topic 2: atmosphere, would, much, like, get
# Topic 1: km, would, asteroid, diameter, impact
# Top Topics for https://news.ycombinator.com/item?id=37159680: Topic 2: atmosphere, would, much, like, get; Topic 1: km, would, asteroid, diameter, impact
# Processing URL: https://news.ycombinator.com/item?id=37153862 with 5 comments.
# Topic 0: 0.026*"rust" + 0.026*"standard" + 0.026*"still" + 0.026*"go" + 0.026*"library"
# Topic 1: 0.039*"module" + 0.028*"programs" + 0.028*"abstract" + 0.028*"im" + 0.028*"use"
# Topic 2: module, programs, abstract, im, use
# Topic 1: rust, standard, still, go, library
# Top Topics for https://news.ycombinator.com/item?id=37153862: Topic 2: module, programs, abstract, im, use; Topic 1: rust, standard, still, go, library
# Processing URL: https://news.ycombinator.com/item?id=37154840 with 58 comments.
# Topic 0: 0.013*"copyright" + 0.011*"use" + 0.009*"code" + 0.008*"output" + 0.008*"llm"
# Topic 1: 0.010*"use" + 0.010*"data" + 0.009*"copyright" + 0.009*"case" + 0.006*"would"
# Topic 1: copyright, use, code, output, llm
# Top Topics for https://news.ycombinator.com/item?id=37154840: Topic 1: copyright, use, code, output, llm
# Processing URL: https://news.ycombinator.com/item?id=37125118 with 32 comments.
# Topic 0: 0.013*"know" + 0.010*"llm" + 0.010*"like" + 0.009*"chatgpt" + 0.009*"answer"
# Topic 1: 0.024*"grammar" + 0.013*"language" + 0.012*"generate" + 0.012*"text" + 0.010*"llm"
# Topic 1: know, llm, like, chatgpt, answer
# Top Topics for https://news.ycombinator.com/item?id=37125118: Topic 1: know, llm, like, chatgpt, answer
# Processing URL: https://news.ycombinator.com/item?id=37137110 with 1 comments.
# Topic 0: 0.143*"chat" + 0.143*"summary" + 0.143*"httpschatopenaicomsharebdeacbaccfbcad" + 0.143*"tldr" + 0.143*"gpt"
# Topic 1: 0.143*"thing" + 0.143*"pages" + 0.143*"gpt" + 0.143*"tldr" + 0.143*"httpschatopenaicomsharebdeacbaccfbcad"
# Topic 1: chat, summary, httpschatopenaicomsharebdeacbaccfbcad, tldr, gpt
# Topic 2: thing, pages, gpt, tldr, httpschatopenaicomsharebdeacbaccfbcad
# Top Topics for https://news.ycombinator.com/item?id=37137110: Topic 1: chat, summary, httpschatopenaicomsharebdeacbaccfbcad, tldr, gpt; Topic 2: thing, pages, gpt, tldr, httpschatopenaicomsharebdeacbaccfbcad
# Processing URL: https://news.ycombinator.com/item?id=37126182 with 44 comments.
# Topic 0: 0.015*"chatgpt" + 0.011*"use" + 0.010*"dont" + 0.008*"time" + 0.008*"much"
# Topic 1: 0.010*"code" + 0.008*"chatgpt" + 0.007*"problems" + 0.006*"hard" + 0.006*"get"
# Topic 1: chatgpt, use, dont, time, much
# Topic 2: code, chatgpt, problems, hard, get
# Top Topics for https://news.ycombinator.com/item?id=37126182: Topic 1: chatgpt, use, dont, time, much; Topic 2: code, chatgpt, problems, hard, get
# Processing URL: https://news.ycombinator.com/item?id=37120982 with 12 comments.
# Topic 0: 0.010*"answer" + 0.010*"questions" + 0.010*"question" + 0.009*"know" + 0.008*"people"
# Topic 1: 0.019*"question" + 0.015*"questions" + 0.013*"dont" + 0.008*"answers" + 0.008*"asked"
# Topic 1: answer, questions, question, know, people
# Top Topics for https://news.ycombinator.com/item?id=37120982: Topic 1: answer, questions, question, know, people
# Processing URL: https://news.ycombinator.com/item?id=37130531 with 5 comments.
# Topic 0: 0.041*"dan" + 0.029*"prompt" + 0.029*"im" + 0.029*"engineer" + 0.029*"would"
# Topic 1: 0.024*"would" + 0.024*"using" + 0.024*"right" + 0.024*"filler" + 0.024*"div"
# Topic 2: would, using, right, filler, div
# Topic 1: dan, prompt, im, engineer, would
# Top Topics for https://news.ycombinator.com/item?id=37130531: Topic 2: would, using, right, filler, div; Topic 1: dan, prompt, im, engineer, would
# Processing URL: https://news.ycombinator.com/item?id=37119112 with 4 comments.
# Topic 0: 0.017*"language" + 0.017*"used" + 0.017*"good" + 0.017*"dont" + 0.017*"stuff"
# Topic 1: 0.030*"gpt" + 0.022*"pretty" + 0.022*"writing" + 0.022*"stuff" + 0.022*"dont"
# Topic 1: language, used, good, dont, stuff
# Top Topics for https://news.ycombinator.com/item?id=37119112: Topic 1: language, used, good, dont, stuff
# Processing URL: https://news.ycombinator.com/item?id=37112741 with 59 comments.
# Topic 0: 0.011*"llama" + 0.008*"data" + 0.007*"gpt" + 0.007*"dont" + 0.007*"model"
# Topic 1: 0.013*"gpt" + 0.012*"llama" + 0.012*"model" + 0.008*"openai" + 0.006*"models"
# Topic 1: llama, data, gpt, dont, model
# Top Topics for https://news.ycombinator.com/item?id=37112741: Topic 1: llama, data, gpt, dont, model
# Processing URL: https://news.ycombinator.com/item?id=37116216 with 19 comments.
# Topic 0: 0.016*"ai" + 0.013*"think" + 0.011*"things" + 0.008*"hes" + 0.008*"bubble"
# Topic 1: 0.024*"ai" + 0.012*"generative" + 0.008*"chatgpt" + 0.008*"agi" + 0.008*"think"
# Topic 2: ai, generative, chatgpt, agi, think
# Topic 1: ai, think, things, hes, bubble
# Top Topics for https://news.ycombinator.com/item?id=37116216: Topic 2: ai, generative, chatgpt, agi, think; Topic 1: ai, think, things, hes, bubble
# Processing URL: https://news.ycombinator.com/item?id=37113307 with 46 comments.
# Topic 0: 0.023*"toki" + 0.020*"pona" + 0.013*"li" + 0.011*"esperanto" + 0.010*"language"
# Topic 1: 0.020*"language" + 0.010*"esperanto" + 0.009*"like" + 0.008*"also" + 0.008*"people"
# Topic 1: toki, pona, li, esperanto, language
# Topic 2: language, esperanto, like, also, people
# Top Topics for https://news.ycombinator.com/item?id=37113307: Topic 1: toki, pona, li, esperanto, language; Topic 2: language, esperanto, like, also, people
# Processing URL: https://news.ycombinator.com/item?id=37106355 with 1 comments.
# Topic 0: 0.335*"chat" + 0.334*"convohttpschatopenaicomsharecffafbbabc" + 0.331*"full"
# Topic 1: 0.334*"full" + 0.333*"convohttpschatopenaicomsharecffafbbabc" + 0.333*"chat"
# Topic 2: full, convohttpschatopenaicomsharecffafbbabc, chat
# Topic 1: chat, convohttpschatopenaicomsharecffafbbabc, full
# Top Topics for https://news.ycombinator.com/item?id=37106355: Topic 2: full, convohttpschatopenaicomsharecffafbbabc, chat; Topic 1: chat, convohttpschatopenaicomsharecffafbbabc, full
# No comments available for URL: https://news.ycombinator.com/item?id=37104621
# Processing URL: https://news.ycombinator.com/item?id=37100153 with 3 comments.
# Topic 0: 0.035*"human" + 0.035*"mostly" + 0.035*"schizophrenic" + 0.035*"go" + 0.035*"thats"
# Topic 1: 0.044*"era" + 0.027*"challenge" + 0.027*"changes" + 0.027*"even" + 0.027*"next"
# Topic 1: human, mostly, schizophrenic, go, thats
# Topic 2: era, challenge, changes, even, next
# Top Topics for https://news.ycombinator.com/item?id=37100153: Topic 1: human, mostly, schizophrenic, go, thats; Topic 2: era, challenge, changes, even, next
# Processing URL: https://news.ycombinator.com/item?id=37076125 with 7 comments.
# Topic 0: 0.033*"game" + 0.028*"food" + 0.023*"snake" + 0.018*"agent" + 0.013*"heres"
# Topic 1: 0.022*"using" + 0.016*"heres" + 0.016*"prompt" + 0.016*"one" + 0.016*"chatgpt"
# Topic 1: game, food, snake, agent, heres
# Top Topics for https://news.ycombinator.com/item?id=37076125: Topic 1: game, food, snake, agent, heres
# Processing URL: https://news.ycombinator.com/item?id=37079534 with 33 comments.
# Topic 0: 0.018*"google" + 0.015*"would" + 0.011*"hangouts" + 0.010*"chat" + 0.010*"talk"
# Topic 1: 0.034*"google" + 0.015*"every" + 0.013*"hn" + 0.013*"kill" + 0.011*"docs"
# Topic 2: google, every, hn, kill, docs
# Topic 1: google, would, hangouts, chat, talk
# Top Topics for https://news.ycombinator.com/item?id=37079534: Topic 2: google, every, hn, kill, docs; Topic 1: google, would, hangouts, chat, talk
# Processing URL: https://news.ycombinator.com/item?id=37073701 with 10 comments.
# Topic 0: 0.059*"svg" + 0.053*"respond" + 0.028*"unicorn" + 0.016*"drawings" + 0.016*"prompt"
# Topic 1: 0.033*"svg" + 0.024*"draw" + 0.015*"first" + 0.015*"often" + 0.015*"things"
# Topic 2: svg, draw, first, often, things
# Topic 1: svg, respond, unicorn, drawings, prompt
# Top Topics for https://news.ycombinator.com/item?id=37073701: Topic 2: svg, draw, first, often, things; Topic 1: svg, respond, unicorn, drawings, prompt
# Processing URL: https://news.ycombinator.com/item?id=37070838 with 36 comments.
# Topic 0: 0.012*"word" + 0.008*"times" + 0.007*"chatgpt" + 0.007*"get" + 0.007*"repeat"
# Topic 1: 0.008*"like" + 0.007*"religious" + 0.006*"model" + 0.006*"sure" + 0.006*"often"
# Topic 1: word, times, chatgpt, get, repeat
# Topic 2: like, religious, model, sure, often
# Top Topics for https://news.ycombinator.com/item?id=37070838: Topic 1: word, times, chatgpt, get, repeat; Topic 2: like, religious, model, sure, often
# Processing URL: https://news.ycombinator.com/item?id=37064152 with 12 comments.
# Topic 0: 0.022*"would" + 0.012*"read" + 0.012*"changes" + 0.010*"use" + 0.009*"service"
# Topic 1: 0.024*"service" + 0.021*"change" + 0.018*"tos" + 0.013*"stop" + 0.013*"using"
# Topic 2: service, change, tos, stop, using
# Topic 1: would, read, changes, use, service
# Top Topics for https://news.ycombinator.com/item?id=37064152: Topic 2: service, change, tos, stop, using; Topic 1: would, read, changes, use, service
# Processing URL: https://news.ycombinator.com/item?id=37054241 with 104 comments.
# Topic 0: 0.013*"im" + 0.011*"like" + 0.010*"one" + 0.006*"question" + 0.005*"na"
# Topic 1: 0.008*"get" + 0.005*"instructions" + 0.005*"like" + 0.005*"see" + 0.005*"shared"
# Topic 1: im, like, one, question, na
# Topic 2: get, instructions, like, see, shared
# Top Topics for https://news.ycombinator.com/item?id=37054241: Topic 1: im, like, one, question, na; Topic 2: get, instructions, like, see, shared
# Processing URL: https://news.ycombinator.com/item?id=37050409 with 9 comments.
# Topic 0: 0.049*"solution" + 0.015*"amortized" + 0.012*"operations" + 0.012*"simple" + 0.012*"case"
# Topic 1: 0.016*"time" + 0.016*"dont" + 0.016*"like" + 0.016*"toxic" + 0.016*"average"
# Topic 1: solution, amortized, operations, simple, case
# Topic 2: time, dont, like, toxic, average
# Top Topics for https://news.ycombinator.com/item?id=37050409: Topic 1: solution, amortized, operations, simple, case; Topic 2: time, dont, like, toxic, average
# Processing URL: https://news.ycombinator.com/item?id=37050257 with 173 comments.
# Topic 0: 0.012*"reasoning" + 0.009*"model" + 0.008*"gpt" + 0.005*"people" + 0.005*"reason"
# Topic 1: 0.008*"reasoning" + 0.007*"model" + 0.006*"people" + 0.005*"models" + 0.005*"right"
# Topic 1: reasoning, model, gpt, people, reason
# Top Topics for https://news.ycombinator.com/item?id=37050257: Topic 1: reasoning, model, gpt, people, reason
# Processing URL: https://news.ycombinator.com/item?id=37034994 with 9 comments.
# Topic 0: 0.042*"code" + 0.032*"array" + 0.028*"object" + 0.015*"invariants" + 0.015*"think"
# Topic 1: 0.028*"invariant" + 0.023*"true" + 0.023*"loop" + 0.018*"example" + 0.018*"invariants"
# Topic 2: invariant, true, loop, example, invariants
# Topic 1: code, array, object, invariants, think
# Top Topics for https://news.ycombinator.com/item?id=37034994: Topic 2: invariant, true, loop, example, invariants; Topic 1: code, array, object, invariants, think
# No comments available for URL: https://news.ycombinator.com/item?id=37030852
# Processing URL: https://news.ycombinator.com/item?id=37013114 with 135 comments.
# Topic 0: 0.009*"llm" + 0.009*"llms" + 0.006*"would" + 0.006*"dont" + 0.005*"human"
# Topic 1: 0.008*"human" + 0.008*"better" + 0.007*"dont" + 0.007*"humans" + 0.006*"claim"
# Topic 1: llm, llms, would, dont, human
# Topic 2: human, better, dont, humans, claim
# Top Topics for https://news.ycombinator.com/item?id=37013114: Topic 1: llm, llms, would, dont, human; Topic 2: human, better, dont, humans, claim
# Processing URL: https://news.ycombinator.com/item?id=37000920 with 16 comments.
# Topic 0: 0.013*"code" + 0.011*"would" + 0.010*"like" + 0.010*"prompt" + 0.010*"fix"
# Topic 1: 0.017*"like" + 0.014*"code" + 0.012*"gpt" + 0.011*"copilot" + 0.011*"ive"
# Topic 1: code, would, like, prompt, fix
# Topic 2: like, code, gpt, copilot, ive
# Top Topics for https://news.ycombinator.com/item?id=37000920: Topic 1: code, would, like, prompt, fix; Topic 2: like, code, gpt, copilot, ive
# Processing URL: https://news.ycombinator.com/item?id=37003617 with 37 comments.
# Topic 0: 0.008*"structure" + 0.008*"bonds" + 0.007*"even" + 0.007*"molecular" + 0.006*"see"
# Topic 1: 0.029*"cells" + 0.028*"cancer" + 0.012*"healthy" + 0.010*"drug" + 0.008*"pcna"
# Topic 1: structure, bonds, even, molecular, see
# Top Topics for https://news.ycombinator.com/item?id=37003617: Topic 1: structure, bonds, even, molecular, see
# Processing URL: https://news.ycombinator.com/item?id=36994214 with 406 comments.
# /var/folders/97/647824bx44z45xbxdnvmph0d4wrhx0/T/ipykernel_17330/2765344242.py:5: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   comment = BeautifulSoup(comment, "html.parser").get_text()
# Topic 0: 0.008*"would" + 0.007*"energy" + 0.006*"like" + 0.004*"people" + 0.004*"dont"
# Topic 1: 0.007*"people" + 0.007*"think" + 0.005*"would" + 0.005*"even" + 0.004*"black"
# Topic 2: people, think, would, even, black
# Topic 1: would, energy, like, people, dont
# Top Topics for https://news.ycombinator.com/item?id=36994214: Topic 2: people, think, would, even, black; Topic 1: would, energy, like, people, dont
# Processing URL: https://news.ycombinator.com/item?id=36992985 with 7 comments.
# Topic 0: 0.049*"token" + 0.049*"chat" + 0.049*"anything" + 0.029*"generates" + 0.029*"interesting"
# Topic 1: 0.054*"try" + 0.054*"mistake" + 0.054*"read" + 0.054*"wrong" + 0.033*"interesting"
# Topic 1: token, chat, anything, generates, interesting
# Topic 2: try, mistake, read, wrong, interesting
# Top Topics for https://news.ycombinator.com/item?id=36992985: Topic 1: token, chat, anything, generates, interesting; Topic 2: try, mistake, read, wrong, interesting
# Processing URL: https://news.ycombinator.com/item?id=36973584 with 76 comments.
# Topic 0: 0.009*"god" + 0.006*"would" + 0.006*"like" + 0.005*"created" + 0.005*"scientific"
# Topic 1: 0.006*"time" + 0.006*"one" + 0.006*"way" + 0.005*"ai" + 0.005*"people"
# Topic 1: god, would, like, created, scientific
# Topic 2: time, one, way, ai, people
# Top Topics for https://news.ycombinator.com/item?id=36973584: Topic 1: god, would, like, created, scientific; Topic 2: time, one, way, ai, people
# Processing URL: https://news.ycombinator.com/item?id=36969897 with 4 comments.
# Topic 0: 0.021*"data" + 0.021*"test" + 0.021*"result" + 0.013*"rust" + 0.013*"well"
# Topic 1: 0.036*"llama" + 0.020*"model" + 0.020*"fine" + 0.020*"like" + 0.020*"may"
# Topic 1: data, test, result, rust, well
# Topic 2: llama, model, fine, like, may
# Top Topics for https://news.ycombinator.com/item?id=36969897: Topic 1: data, test, result, rust, well; Topic 2: llama, model, fine, like, may
# Processing URL: https://news.ycombinator.com/item?id=36964752 with 1 comments.
# Topic 0: 0.077*"read" + 0.077*"httpschatopenaicomsharedfaeefbbc" + 0.077*"chatgpt" + 0.077*"building" + 0.077*"inspired"
# Topic 1: 0.077*"pun" + 0.077*"one" + 0.077*"little" + 0.077*"conversations" + 0.077*"built"
# Topic 2: pun, one, little, conversations, built
# Topic 1: read, httpschatopenaicomsharedfaeefbbc, chatgpt, building, inspired
# Top Topics for https://news.ycombinator.com/item?id=36964752: Topic 2: pun, one, little, conversations, built; Topic 1: read, httpschatopenaicomsharedfaeefbbc, chatgpt, building, inspired
# Processing URL: https://news.ycombinator.com/item?id=36952640 with 8 comments.
# Topic 0: 0.044*"molecular" + 0.032*"properties" + 0.032*"trying" + 0.032*"understand" + 0.032*"text"
# Topic 1: 0.046*"gpt" + 0.045*"anything" + 0.028*"curious" + 0.028*"know" + 0.027*"material"
# Topic 1: molecular, properties, trying, understand, text
# Topic 2: gpt, anything, curious, know, material
# Top Topics for https://news.ycombinator.com/item?id=36952640: Topic 1: molecular, properties, trying, understand, text; Topic 2: gpt, anything, curious, know, material
# Processing URL: https://news.ycombinator.com/item?id=36956825 with 1 comments.
# Topic 0: 0.020*"gpt" + 0.020*"answer" + 0.020*"first" + 0.020*"ive" + 0.020*"wrongin"
# Topic 1: 0.097*"gpt" + 0.051*"answer" + 0.040*"first" + 0.028*"ive" + 0.017*"cases"
# Topic 1: gpt, answer, first, ive, wrongin
# Top Topics for https://news.ycombinator.com/item?id=36956825: Topic 1: gpt, answer, first, ive, wrongin
# Processing URL: https://news.ycombinator.com/item?id=36949931 with 67 comments.
# Topic 0: 0.008*"like" + 0.007*"ligma" + 0.007*"dont" + 0.007*"mistakes" + 0.005*"chatgpt"
# Topic 1: 0.009*"instructions" + 0.007*"information" + 0.006*"user" + 0.006*"chatgpt" + 0.005*"better"
# Topic 1: like, ligma, dont, mistakes, chatgpt
# Top Topics for https://news.ycombinator.com/item?id=36949931: Topic 1: like, ligma, dont, mistakes, chatgpt
# No comments available for URL: https://news.ycombinator.com/item?id=36950116
# Processing URL: https://news.ycombinator.com/item?id=36932333 with 9 comments.
# Topic 0: 0.027*"like" + 0.019*"snarky" + 0.019*"even" + 0.019*"away" + 0.019*"understand"
# Topic 1: 0.036*"mvp" + 0.025*"metaphors" + 0.025*"sports" + 0.015*"common" + 0.015*"usp"
# Topic 2: mvp, metaphors, sports, common, usp
# Topic 1: like, snarky, even, away, understand
# Top Topics for https://news.ycombinator.com/item?id=36932333: Topic 2: mvp, metaphors, sports, common, usp; Topic 1: like, snarky, even, away, understand
# Processing URL: https://news.ycombinator.com/item?id=36912513 with 2 comments.
# Topic 0: 0.120*"somewhere" + 0.120*"ends" + 0.120*"tops" + 0.120*"give" + 0.120*"years"
# Topic 1: 0.111*"already" + 0.111*"understands" + 0.111*"languages" + 0.111*"httpschatopenaicomshareacfabdec" + 0.111*"ahead"
# Topic 2: already, understands, languages, httpschatopenaicomshareacfabdec, ahead
# Topic 1: somewhere, ends, tops, give, years
# Top Topics for https://news.ycombinator.com/item?id=36912513: Topic 2: already, understands, languages, httpschatopenaicomshareacfabdec, ahead; Topic 1: somewhere, ends, tops, give, years
# Processing URL: https://news.ycombinator.com/item?id=36894198 with 1 comments.
# Topic 0: 0.006*"dhcp" + 0.005*"rules" + 0.005*"ip" + 0.005*"firewall" + 0.005*"iptables"
# Topic 1: 0.064*"dhcp" + 0.029*"rules" + 0.027*"ip" + 0.022*"traffic" + 0.022*"iptables"
# Topic 1: dhcp, rules, ip, firewall, iptables
# Top Topics for https://news.ycombinator.com/item?id=36894198: Topic 1: dhcp, rules, ip, firewall, iptables
# Processing URL: https://news.ycombinator.com/item?id=36905076 with 3 comments.
# Topic 0: 0.029*"also" + 0.029*"paper" + 0.029*"similar" + 0.029*"planning" + 0.017*"mentioned"
# Topic 1: 0.041*"planning" + 0.023*"human" + 0.023*"loop" + 0.014*"also" + 0.014*"ai"
# Topic 1: also, paper, similar, planning, mentioned
# Top Topics for https://news.ycombinator.com/item?id=36905076: Topic 1: also, paper, similar, planning, mentioned
# Processing URL: https://news.ycombinator.com/item?id=36897250 with 1 comments.
# Topic 0: 0.252*"sample" + 0.250*"check" + 0.249*"httpschatopenaicomsharebbdcdaaf" + 0.249*"conversation"
# Topic 1: 0.251*"conversation" + 0.250*"httpschatopenaicomsharebbdcdaaf" + 0.250*"check" + 0.249*"sample"
# Topic 2: conversation, httpschatopenaicomsharebbdcdaaf, check, sample
# Topic 1: sample, check, httpschatopenaicomsharebbdcdaaf, conversation
# Top Topics for https://news.ycombinator.com/item?id=36897250: Topic 2: conversation, httpschatopenaicomsharebbdcdaaf, check, sample; Topic 1: sample, check, httpschatopenaicomsharebbdcdaaf, conversation
# Processing URL: https://news.ycombinator.com/item?id=36862850 with 130 comments.
# Topic 0: 0.011*"people" + 0.008*"ai" + 0.008*"would" + 0.007*"human" + 0.006*"dont"
# Topic 1: 0.012*"ai" + 0.010*"tool" + 0.007*"like" + 0.006*"dont" + 0.006*"could"
# Topic 2: ai, tool, like, dont, could
# Topic 1: people, ai, would, human, dont
# Top Topics for https://news.ycombinator.com/item?id=36862850: Topic 2: ai, tool, like, dont, could; Topic 1: people, ai, would, human, dont
# Processing URL: https://news.ycombinator.com/item?id=36852545 with 1 comments.
# Topic 0: 0.047*"alda" + 0.028*"unit" + 0.028*"metersthat" + 0.028*"mongolian" + 0.028*"outstretched"
# Topic 1: 0.029*"alda" + 0.029*"measurement" + 0.029*"traditional" + 0.029*"wide" + 0.029*"code"
# Topic 1: alda, unit, metersthat, mongolian, outstretched
# Topic 2: alda, measurement, traditional, wide, code
# Top Topics for https://news.ycombinator.com/item?id=36852545: Topic 1: alda, unit, metersthat, mongolian, outstretched; Topic 2: alda, measurement, traditional, wide, code
# Processing URL: https://news.ycombinator.com/item?id=36855516 with 60 comments.
# Topic 0: 0.008*"llm" + 0.008*"tried" + 0.008*"use" + 0.007*"chatgpt" + 0.007*"answer"
# Topic 1: 0.012*"chatgpt" + 0.011*"gpt" + 0.010*"answer" + 0.009*"question" + 0.009*"one"
# Topic 1: llm, tried, use, chatgpt, answer
# Top Topics for https://news.ycombinator.com/item?id=36855516: Topic 1: llm, tried, use, chatgpt, answer
# Processing URL: https://news.ycombinator.com/item?id=36821808 with 8 comments.
# Topic 0: 0.032*"metal" + 0.028*"death" + 0.023*"chatgpt" + 0.023*"english" + 0.019*"could"
# Topic 1: 0.027*"english" + 0.015*"metal" + 0.015*"one" + 0.015*"single" + 0.015*"made"
# Topic 1: metal, death, chatgpt, english, could
# Topic 2: english, metal, one, single, made
# Top Topics for https://news.ycombinator.com/item?id=36821808: Topic 1: metal, death, chatgpt, english, could; Topic 2: english, metal, one, single, made
# Processing URL: https://news.ycombinator.com/item?id=36828409 with 48 comments.
# Topic 0: 0.010*"customer" + 0.009*"support" + 0.007*"dont" + 0.007*"chat" + 0.007*"bot"
# Topic 1: 0.009*"people" + 0.008*"code" + 0.006*"support" + 0.006*"time" + 0.006*"good"
# Topic 1: customer, support, dont, chat, bot
# Topic 2: people, code, support, time, good
# Top Topics for https://news.ycombinator.com/item?id=36828409: Topic 1: customer, support, dont, chat, bot; Topic 2: people, code, support, time, good
# Processing URL: https://news.ycombinator.com/item?id=36802289 with 52 comments.
# Topic 0: 0.016*"gold" + 0.015*"would" + 0.011*"earth" + 0.009*"metals" + 0.009*"market"
# Topic 1: 0.013*"gold" + 0.010*"could" + 0.008*"earth" + 0.007*"space" + 0.007*"water"
# Topic 1: gold, would, earth, metals, market
# Topic 2: gold, could, earth, space, water
# Top Topics for https://news.ycombinator.com/item?id=36802289: Topic 1: gold, would, earth, metals, market; Topic 2: gold, could, earth, space, water
# Processing URL: https://news.ycombinator.com/item?id=36803744 with 19 comments.
# Topic 0: 0.014*"text" + 0.014*"user" + 0.012*"brain" + 0.011*"think" + 0.011*"model"
# Topic 1: 0.024*"prompt" + 0.012*"system" + 0.012*"say" + 0.010*"never" + 0.010*"please"
# Topic 1: text, user, brain, think, model
# Top Topics for https://news.ycombinator.com/item?id=36803744: Topic 1: text, user, brain, think, model
# Processing URL: https://news.ycombinator.com/item?id=36800789 with 1 comments.
# Topic 0: 0.100*"google" + 0.100*"websitehttpschatopenaicomsharefcabebfae" + 0.100*"chatgpt" + 0.100*"ask" + 0.100*"instead"
# Topic 1: 0.100*"joeyhname" + 0.100*"interesting" + 0.100*"better" + 0.100*"something" + 0.100*"nowtell"
# Topic 2: joeyhname, interesting, better, something, nowtell
# Topic 1: google, websitehttpschatopenaicomsharefcabebfae, chatgpt, ask, instead
# Top Topics for https://news.ycombinator.com/item?id=36800789: Topic 2: joeyhname, interesting, better, something, nowtell; Topic 1: google, websitehttpschatopenaicomsharefcabebfae, chatgpt, ask, instead
# Processing URL: https://news.ycombinator.com/item?id=36795173 with 43 comments.
# Topic 0: 0.012*"cancer" + 0.006*"enough" + 0.006*"way" + 0.005*"care" + 0.005*"like"
# Topic 1: 0.016*"medical" + 0.012*"cancer" + 0.006*"people" + 0.006*"doctors" + 0.005*"thats"
# Topic 2: medical, cancer, people, doctors, thats
# Topic 1: cancer, enough, way, care, like
# Top Topics for https://news.ycombinator.com/item?id=36795173: Topic 2: medical, cancer, people, doctors, thats; Topic 1: cancer, enough, way, care, like
# Processing URL: https://news.ycombinator.com/item?id=36798395 with 17 comments.
# Topic 0: 0.023*"one" + 0.014*"pressure" + 0.011*"staggered" + 0.011*"story" + 0.009*"clarke"
# Topic 1: 0.011*"good" + 0.011*"story" + 0.011*"chatgpt" + 0.011*"book" + 0.008*"like"
# Topic 1: one, pressure, staggered, story, clarke
# Top Topics for https://news.ycombinator.com/item?id=36798395: Topic 1: one, pressure, staggered, story, clarke
# Processing URL: https://news.ycombinator.com/item?id=36786407 with 126 comments.
# Topic 0: 0.009*"gpt" + 0.007*"code" + 0.006*"people" + 0.006*"like" + 0.004*"use"
# Topic 1: 0.006*"dont" + 0.006*"think" + 0.006*"gpt" + 0.005*"like" + 0.005*"ai"
# Topic 1: gpt, code, people, like, use
# Topic 2: dont, think, gpt, like, ai
# Top Topics for https://news.ycombinator.com/item?id=36786407: Topic 1: gpt, code, people, like, use; Topic 2: dont, think, gpt, like, ai
# Processing URL: https://news.ycombinator.com/item?id=36780295 with 6 comments.
# Topic 0: 0.035*"actually" + 0.027*"chatgpt" + 0.019*"lot" + 0.019*"code" + 0.019*"wonder"
# Topic 1: 0.037*"times" + 0.026*"visit" + 0.026*"day" + 0.026*"per" + 0.016*"gpt"
# Topic 1: actually, chatgpt, lot, code, wonder
# Topic 2: times, visit, day, per, gpt
# Top Topics for https://news.ycombinator.com/item?id=36780295: Topic 1: actually, chatgpt, lot, code, wonder; Topic 2: times, visit, day, per, gpt
# Processing URL: https://news.ycombinator.com/item?id=36781015 with 20 comments.
# Topic 0: 0.033*"openai" + 0.017*"azure" + 0.015*"dont" + 0.011*"companies" + 0.010*"api"
# Topic 1: 0.011*"would" + 0.009*"changing" + 0.009*"openai" + 0.008*"api" + 0.007*"course"
# Topic 1: openai, azure, dont, companies, api
# Topic 2: would, changing, openai, api, course
# Top Topics for https://news.ycombinator.com/item?id=36781015: Topic 1: openai, azure, dont, companies, api; Topic 2: would, changing, openai, api, course
# Processing URL: https://news.ycombinator.com/item?id=36774627 with 218 comments.
# Topic 0: 0.008*"model" + 0.007*"dont" + 0.006*"would" + 0.006*"know" + 0.006*"like"
# Topic 1: 0.007*"model" + 0.005*"llama" + 0.005*"language" + 0.005*"gpt" + 0.004*"way"
# Topic 1: model, dont, would, know, like
# Topic 2: model, llama, language, gpt, way
# Top Topics for https://news.ycombinator.com/item?id=36774627: Topic 1: model, dont, would, know, like; Topic 2: model, llama, language, gpt, way
# Processing URL: https://news.ycombinator.com/item?id=36763718 with 24 comments.
# Topic 0: 0.024*"chatgpt" + 0.015*"questions" + 0.013*"question" + 0.013*"would" + 0.011*"stack"
# Topic 1: 0.009*"documentation" + 0.008*"im" + 0.007*"code" + 0.007*"things" + 0.007*"sharepoint"
# Topic 1: chatgpt, questions, question, would, stack
# Top Topics for https://news.ycombinator.com/item?id=36763718: Topic 1: chatgpt, questions, question, would, stack
# No comments available for URL: https://news.ycombinator.com/item?id=36744003
# Processing URL: https://news.ycombinator.com/item?id=36729180 with 3 comments.
# Topic 0: 0.046*"problemsnetflix" + 0.046*"httpschatopenaicomshareebabcfabda" + 0.046*"get" + 0.046*"youre" + 0.046*"apple"
# Topic 1: 0.084*"idea" + 0.080*"better" + 0.080*"problem" + 0.080*"solve" + 0.080*"much"
# Topic 1: problemsnetflix, httpschatopenaicomshareebabcfabda, get, youre, apple
# Topic 2: idea, better, problem, solve, much
# Top Topics for https://news.ycombinator.com/item?id=36729180: Topic 1: problemsnetflix, httpschatopenaicomshareebabcfabda, get, youre, apple; Topic 2: idea, better, problem, solve, much
# Processing URL: https://news.ycombinator.com/item?id=36712403 with 1 comments.
# Topic 0: 0.023*"investment" + 0.022*"sales" + 0.022*"contracts" + 0.022*"contract" + 0.022*"may"
# Topic 1: 0.068*"investment" + 0.044*"contract" + 0.043*"sales" + 0.031*"ruling" + 0.031*"grove"
# Topic 1: investment, sales, contracts, contract, may
# Top Topics for https://news.ycombinator.com/item?id=36712403: Topic 1: investment, sales, contracts, contract, may
# Processing URL: https://news.ycombinator.com/item?id=36709895 with 65 comments.
# Topic 0: 0.008*"web" + 0.008*"worse" + 0.006*"chatgpt" + 0.006*"im" + 0.006*"google"
# Topic 1: 0.021*"code" + 0.014*"output" + 0.008*"results" + 0.008*"prime" + 0.007*"google"
# Topic 1: web, worse, chatgpt, im, google
# Top Topics for https://news.ycombinator.com/item?id=36709895: Topic 1: web, worse, chatgpt, im, google
# Processing URL: https://news.ycombinator.com/item?id=36697160 with 3 comments.
# Topic 0: 0.065*"sqlite" + 0.022*"code" + 0.022*"interpreter" + 0.022*"database" + 0.022*"upload"
# Topic 1: 0.043*"gpt" + 0.031*"code" + 0.031*"sqlite" + 0.031*"used" + 0.019*"sql"
# Topic 1: sqlite, code, interpreter, database, upload
# Topic 2: gpt, code, sqlite, used, sql
# Top Topics for https://news.ycombinator.com/item?id=36697160: Topic 1: sqlite, code, interpreter, database, upload; Topic 2: gpt, code, sqlite, used, sql
# Processing URL: https://news.ycombinator.com/item?id=36675729 with 4 comments.
# Topic 0: 0.027*"apologize" + 0.027*"times" + 0.027*"repeat" + 0.027*"trigger" + 0.016*"type"
# Topic 1: 0.027*"response" + 0.027*"seems" + 0.027*"word" + 0.027*"apologize" + 0.016*"request"
# Topic 2: response, seems, word, apologize, request
# Topic 1: apologize, times, repeat, trigger, type
# Top Topics for https://news.ycombinator.com/item?id=36675729: Topic 2: response, seems, word, apologize, request; Topic 1: apologize, times, repeat, trigger, type
# Processing URL: https://news.ycombinator.com/item?id=36664604 with 1 comments.
# Topic 0: 0.083*"pretty" + 0.083*"able" + 0.083*"chatgpt" + 0.083*"idea" + 0.083*"httpschatopenaicomsharedeceabca"
# Topic 1: 0.132*"pretty" + 0.079*"cool" + 0.079*"generate" + 0.079*"similar" + 0.079*"quick"
# Topic 2: pretty, cool, generate, similar, quick
# Topic 1: pretty, able, chatgpt, idea, httpschatopenaicomsharedeceabca
# Top Topics for https://news.ycombinator.com/item?id=36664604: Topic 2: pretty, cool, generate, similar, quick; Topic 1: pretty, able, chatgpt, idea, httpschatopenaicomsharedeceabca
# Processing URL: https://news.ycombinator.com/item?id=36666922 with 6 comments.
# Topic 0: 0.026*"gpt" + 0.019*"things" + 0.019*"gptturbo" + 0.019*"rust" + 0.019*"wrote"
# Topic 1: 0.024*"example" + 0.019*"question" + 0.019*"im" + 0.019*"based" + 0.013*"bit"
# Topic 1: gpt, things, gptturbo, rust, wrote
# Topic 2: example, question, im, based, bit
# Top Topics for https://news.ycombinator.com/item?id=36666922: Topic 1: gpt, things, gptturbo, rust, wrote; Topic 2: example, question, im, based, bit
# Processing URL: https://news.ycombinator.com/item?id=36652117 with 13 comments.
# Topic 0: 0.022*"key" + 0.016*"important" + 0.016*"crucial" + 0.014*"marriage" + 0.014*"vital"
# Topic 1: 0.016*"important" + 0.015*"used" + 0.015*"parents" + 0.013*"crucial" + 0.010*"key"
# Topic 1: key, important, crucial, marriage, vital
# Top Topics for https://news.ycombinator.com/item?id=36652117: Topic 1: key, important, crucial, marriage, vital
# Processing URL: https://news.ycombinator.com/item?id=36658959 with 22 comments.
# Topic 0: 0.015*"ai" + 0.011*"humans" + 0.009*"think" + 0.009*"time" + 0.009*"solve"
# Topic 1: 0.008*"like" + 0.008*"reading" + 0.008*"different" + 0.007*"humans" + 0.007*"think"
# Topic 1: ai, humans, think, time, solve
# Top Topics for https://news.ycombinator.com/item?id=36658959: Topic 1: ai, humans, think, time, solve
# Processing URL: https://news.ycombinator.com/item?id=36645575 with 5 comments.
# Topic 0: 0.019*"available" + 0.019*"case" + 0.019*"using" + 0.019*"indeed" + 0.019*"tools"
# Topic 1: 0.019*"dont" + 0.019*"building" + 0.019*"really" + 0.019*"abstractions" + 0.019*"seems"
# Topic 1: available, case, using, indeed, tools
# Top Topics for https://news.ycombinator.com/item?id=36645575: Topic 1: available, case, using, indeed, tools
# Processing URL: https://news.ycombinator.com/item?id=36636039 with 139 comments.
# Topic 0: 0.011*"chatgpt" + 0.009*"use" + 0.005*"like" + 0.005*"google" + 0.005*"im"
# Topic 1: 0.006*"models" + 0.006*"dont" + 0.006*"like" + 0.005*"gpt" + 0.005*"good"
# Topic 1: chatgpt, use, like, google, im
# Topic 2: models, dont, like, gpt, good
# Top Topics for https://news.ycombinator.com/item?id=36636039: Topic 1: chatgpt, use, like, google, im; Topic 2: models, dont, like, gpt, good
# Processing URL: https://news.ycombinator.com/item?id=36619481 with 35 comments.
# Topic 0: 0.022*"rds" + 0.020*"lambda" + 0.015*"instance" + 0.012*"function" + 0.009*"aws"
# Topic 1: 0.012*"chatgpt" + 0.010*"using" + 0.008*"answer" + 0.008*"answers" + 0.007*"would"
# Topic 1: rds, lambda, instance, function, aws
# Topic 2: chatgpt, using, answer, answers, would
# Top Topics for https://news.ycombinator.com/item?id=36619481: Topic 1: rds, lambda, instance, function, aws; Topic 2: chatgpt, using, answer, answers, would
# Processing URL: https://news.ycombinator.com/item?id=36633995 with 17 comments.
# Topic 0: 0.010*"prompt" + 0.009*"medical" + 0.008*"dont" + 0.008*"think" + 0.008*"provide"
# Topic 1: 0.119*"liter" + 0.116*"jug" + 0.048*"liters" + 0.030*"water" + 0.018*"pour"
# Topic 2: liter, jug, liters, water, pour
# Topic 1: prompt, medical, dont, think, provide
# Top Topics for https://news.ycombinator.com/item?id=36633995: Topic 2: liter, jug, liters, water, pour; Topic 1: prompt, medical, dont, think, provide
# Processing URL: https://news.ycombinator.com/item?id=36621120 with 61 comments.
# Topic 0: 0.015*"gpt" + 0.014*"chatgpt" + 0.011*"api" + 0.009*"model" + 0.009*"models"
# Topic 1: 0.011*"gpt" + 0.007*"thats" + 0.007*"even" + 0.006*"ive" + 0.005*"thought"
# Topic 1: gpt, chatgpt, api, model, models
# Top Topics for https://news.ycombinator.com/item?id=36621120: Topic 1: gpt, chatgpt, api, model, models
# No comments available for URL: https://news.ycombinator.com/item?id=36617139
# Processing URL: https://news.ycombinator.com/item?id=36605806 with 4 comments.
# Topic 0: 0.038*"would" + 0.024*"strategy" + 0.024*"could" + 0.017*"openai" + 0.017*"developers"
# Topic 1: 0.031*"user" + 0.024*"way" + 0.024*"users" + 0.017*"openai" + 0.017*"directly"
# Topic 1: would, strategy, could, openai, developers
# Top Topics for https://news.ycombinator.com/item?id=36605806: Topic 1: would, strategy, could, openai, developers
# Processing URL: https://news.ycombinator.com/item?id=36599949 with 1 comments.
# Topic 0: 0.052*"unique" + 0.052*"hiring" + 0.052*"organizations" + 0.052*"ways" + 0.052*"reply"
# Topic 1: 0.035*"reply" + 0.035*"ways" + 0.035*"organizations" + 0.035*"hiring" + 0.035*"unique"
# Topic 1: unique, hiring, organizations, ways, reply
# Topic 2: reply, ways, organizations, hiring, unique
# Top Topics for https://news.ycombinator.com/item?id=36599949: Topic 1: unique, hiring, organizations, ways, reply; Topic 2: reply, ways, organizations, hiring, unique
# Processing URL: https://news.ycombinator.com/item?id=36597709 with 3 comments.
# Topic 0: 0.023*"process" + 0.014*"someone" + 0.014*"describing" + 0.014*"iterative" + 0.014*"youre"
# Topic 1: 0.021*"ai" + 0.018*"software" + 0.015*"need" + 0.015*"cant" + 0.011*"code"
# Topic 1: process, someone, describing, iterative, youre
# Top Topics for https://news.ycombinator.com/item?id=36597709: Topic 1: process, someone, describing, iterative, youre
# Processing URL: https://news.ycombinator.com/item?id=36586248 with 14 comments.
# Topic 0: 0.018*"csv" + 0.013*"code" + 0.013*"ask" + 0.010*"like" + 0.010*"look"
# Topic 1: 0.016*"learn" + 0.016*"code" + 0.011*"level" + 0.011*"need" + 0.011*"old"
# Topic 1: csv, code, ask, like, look
# Topic 2: learn, code, level, need, old
# Top Topics for https://news.ycombinator.com/item?id=36586248: Topic 1: csv, code, ask, like, look; Topic 2: learn, code, level, need, old
# Processing URL: https://news.ycombinator.com/item?id=36580837 with 8 comments.
# Topic 0: 0.012*"ais" + 0.012*"listen" + 0.012*"dont" + 0.010*"try" + 0.010*"knowledge"
# Topic 1: 0.016*"ai" + 0.014*"knowledge" + 0.014*"subject" + 0.014*"idea" + 0.011*"point"
# Topic 1: ais, listen, dont, try, knowledge
# Top Topics for https://news.ycombinator.com/item?id=36580837: Topic 1: ais, listen, dont, try, knowledge
# Processing URL: https://news.ycombinator.com/item?id=36568192 with 20 comments.
# Topic 0: 0.012*"real" + 0.012*"words" + 0.012*"use" + 0.010*"dont" + 0.010*"like"
# Topic 1: 0.017*"fizzbuzz" + 0.008*"need" + 0.006*"high" + 0.006*"one" + 0.006*"decoupler"
# Topic 2: fizzbuzz, need, high, one, decoupler
# Topic 1: real, words, use, dont, like
# Top Topics for https://news.ycombinator.com/item?id=36568192: Topic 2: fizzbuzz, need, high, one, decoupler; Topic 1: real, words, use, dont, like
# Processing URL: https://news.ycombinator.com/item?id=36562502 with 26 comments.
# Topic 0: 0.009*"deep" + 0.007*"also" + 0.007*"understand" + 0.007*"ai" + 0.007*"going"
# Topic 1: 0.013*"get" + 0.011*"python" + 0.010*"learn" + 0.008*"good" + 0.008*"diffusion"
# Topic 1: deep, also, understand, ai, going
# Topic 2: get, python, learn, good, diffusion
# Top Topics for https://news.ycombinator.com/item?id=36562502: Topic 1: deep, also, understand, ai, going; Topic 2: get, python, learn, good, diffusion
# Processing URL: https://news.ycombinator.com/item?id=36567918 with 244 comments.
# Topic 0: 0.010*"ai" + 0.007*"dont" + 0.006*"like" + 0.006*"people" + 0.005*"chatgpt"
# Topic 1: 0.006*"ai" + 0.004*"people" + 0.004*"thats" + 0.004*"like" + 0.004*"would"
# Topic 1: ai, dont, like, people, chatgpt
# Top Topics for https://news.ycombinator.com/item?id=36567918: Topic 1: ai, dont, like, people, chatgpt
# Processing URL: https://news.ycombinator.com/item?id=36565854 with 39 comments.
# Topic 0: 0.014*"people" + 0.013*"intelligent" + 0.012*"sudoku" + 0.011*"solve" + 0.010*"llms"
# Topic 1: 0.012*"one" + 0.011*"think" + 0.010*"gpt" + 0.008*"im" + 0.007*"dont"
# Topic 1: people, intelligent, sudoku, solve, llms
# Topic 2: one, think, gpt, im, dont
# Top Topics for https://news.ycombinator.com/item?id=36565854: Topic 1: people, intelligent, sudoku, solve, llms; Topic 2: one, think, gpt, im, dont
# Processing URL: https://news.ycombinator.com/item?id=36565225 with 5 comments.
# Topic 0: 0.029*"java" + 0.029*"dependencies" + 0.029*"mainjava" + 0.029*"orgapachehadoopfspath" + 0.029*"thats"
# Topic 1: 0.045*"well" + 0.035*"works" + 0.034*"answers" + 0.034*"questions" + 0.025*"hadoop"
# Topic 1: java, dependencies, mainjava, orgapachehadoopfspath, thats
# Topic 2: well, works, answers, questions, hadoop
# Top Topics for https://news.ycombinator.com/item?id=36565225: Topic 1: java, dependencies, mainjava, orgapachehadoopfspath, thats; Topic 2: well, works, answers, questions, hadoop
# Processing URL: https://news.ycombinator.com/item?id=36553987 with 75 comments.
# Topic 0: 0.007*"much" + 0.007*"work" + 0.007*"people" + 0.006*"use" + 0.005*"write"
# Topic 1: 0.006*"would" + 0.006*"im" + 0.006*"ask" + 0.006*"work" + 0.005*"dont"
# Topic 1: much, work, people, use, write
# Topic 2: would, im, ask, work, dont
# Top Topics for https://news.ycombinator.com/item?id=36553987: Topic 1: much, work, people, use, write; Topic 2: would, im, ask, work, dont
# Processing URL: https://news.ycombinator.com/item?id=36542267 with 7 comments.
# Topic 0: 0.022*"mdn" + 0.022*"blah" + 0.022*"owd" + 0.017*"content" + 0.012*"ads"
# Topic 1: 0.017*"ai" + 0.017*"mozilla" + 0.017*"mdn" + 0.014*"team" + 0.014*"community"
# Topic 2: ai, mozilla, mdn, team, community
# Topic 1: mdn, blah, owd, content, ads
# Top Topics for https://news.ycombinator.com/item?id=36542267: Topic 2: ai, mozilla, mdn, team, community; Topic 1: mdn, blah, owd, content, ads
# Processing URL: https://news.ycombinator.com/item?id=36552324 with 108 comments.
# Topic 0: 0.017*"twitter" + 0.009*"get" + 0.007*"people" + 0.007*"would" + 0.006*"elon"
# Topic 1: 0.012*"twitter" + 0.007*"musk" + 0.006*"like" + 0.006*"billion" + 0.006*"would"
# Topic 2: twitter, musk, like, billion, would
# Topic 1: twitter, get, people, would, elon
# Top Topics for https://news.ycombinator.com/item?id=36552324: Topic 2: twitter, musk, like, billion, would; Topic 1: twitter, get, people, would, elon
# No comments available for URL: https://news.ycombinator.com/item?id=36536184
# Processing URL: https://news.ycombinator.com/item?id=36527423 with 8 comments.
# Topic 0: 0.016*"tell" + 0.016*"sales" + 0.015*"spark" + 0.011*"sleep" + 0.011*"ones"
# Topic 1: 0.020*"oh" + 0.009*"sure" + 0.009*"tell" + 0.009*"expecting" + 0.009*"well"
# Topic 2: oh, sure, tell, expecting, well
# Topic 1: tell, sales, spark, sleep, ones
# Top Topics for https://news.ycombinator.com/item?id=36527423: Topic 2: oh, sure, tell, expecting, well; Topic 1: tell, sales, spark, sleep, ones
# No comments available for URL: https://news.ycombinator.com/item?id=36502130
# Processing URL: https://news.ycombinator.com/item?id=36492149 with 10 comments.
# Topic 0: 0.030*"occupation" + 0.024*"organization" + 0.016*"namefamily" + 0.014*"also" + 0.012*"records"
# Topic 1: 0.025*"like" + 0.022*"llm" + 0.020*"name" + 0.018*"answer" + 0.013*"question"
# Topic 1: occupation, organization, namefamily, also, records
# Topic 2: like, llm, name, answer, question
# Top Topics for https://news.ycombinator.com/item?id=36492149: Topic 1: occupation, organization, namefamily, also, records; Topic 2: like, llm, name, answer, question
# Processing URL: https://news.ycombinator.com/item?id=36492329 with 18 comments.
# Topic 0: 0.014*"people" + 0.014*"believe" + 0.014*"chrome" + 0.014*"something" + 0.014*"write"
# Topic 1: 0.026*"people" + 0.022*"like" + 0.021*"know" + 0.021*"believe" + 0.017*"microsoft"
# Topic 2: people, like, know, believe, microsoft
# Topic 1: people, believe, chrome, something, write
# Top Topics for https://news.ycombinator.com/item?id=36492329: Topic 2: people, like, know, believe, microsoft; Topic 1: people, believe, chrome, something, write
# Processing URL: https://news.ycombinator.com/item?id=36483445 with 6 comments.
# Topic 0: 0.026*"llm" + 0.026*"said" + 0.026*"summary" + 0.026*"httpschatopenaicomsharebfecbbdbfdeaa" + 0.026*"cant"
# Topic 1: 0.031*"would" + 0.031*"output" + 0.031*"quite" + 0.019*"llm" + 0.019*"something"
# Topic 2: would, output, quite, llm, something
# Topic 1: llm, said, summary, httpschatopenaicomsharebfecbbdbfdeaa, cant
# Top Topics for https://news.ycombinator.com/item?id=36483445: Topic 2: would, output, quite, llm, something; Topic 1: llm, said, summary, httpschatopenaicomsharebfecbbdbfdeaa, cant
# No comments available for URL: https://news.ycombinator.com/item?id=36477567
# Processing URL: https://news.ycombinator.com/item?id=36464128 with 2 comments.
# Topic 0: 0.063*"dependencies" + 0.030*"plugins" + 0.023*"plugin" + 0.023*"virtual" + 0.023*"environments"
# Topic 1: 0.012*"thank" + 0.012*"conversation" + 0.012*"still" + 0.012*"going" + 0.012*"heh"
# Topic 1: dependencies, plugins, plugin, virtual, environments
# Top Topics for https://news.ycombinator.com/item?id=36464128: Topic 1: dependencies, plugins, plugin, virtual, environments
# Processing URL: https://news.ycombinator.com/item?id=36459519 with 3 comments.
# Topic 0: 0.014*"companies" + 0.014*"autogpt" + 0.010*"look" + 0.010*"politicians" + 0.010*"gpt"
# Topic 1: 0.029*"cybersecurity" + 0.015*"act" + 0.015*"advanced" + 0.013*"investment" + 0.013*"grants"
# Topic 1: companies, autogpt, look, politicians, gpt
# Top Topics for https://news.ycombinator.com/item?id=36459519: Topic 1: companies, autogpt, look, politicians, gpt
# Processing URL: https://news.ycombinator.com/item?id=36453856 with 562 comments.
# Topic 0: 0.016*"rule" + 0.009*"rules" + 0.008*"whether" + 0.007*"people" + 0.007*"park"
# Topic 1: 0.013*"people" + 0.012*"park" + 0.011*"rules" + 0.011*"rule" + 0.009*"vehicle"
# Topic 2: people, park, rules, rule, vehicle
# Topic 1: rule, rules, whether, people, park
# Top Topics for https://news.ycombinator.com/item?id=36453856: Topic 2: people, park, rules, rule, vehicle; Topic 1: rule, rules, whether, people, park
# Processing URL: https://news.ycombinator.com/item?id=36434173 with 58 comments.
# Topic 0: 0.009*"like" + 0.008*"would" + 0.007*"still" + 0.006*"controller" + 0.006*"think"
# Topic 1: 0.008*"dont" + 0.007*"engineers" + 0.007*"party" + 0.005*"controller" + 0.005*"people"
# Topic 1: like, would, still, controller, think
# Top Topics for https://news.ycombinator.com/item?id=36434173: Topic 1: like, would, still, controller, think
# Processing URL: https://news.ycombinator.com/item?id=36445085 with 1 comments.
# Topic 0: 0.251*"answer" + 0.250*"articlehttpschatopenaicomsharebfdccfbdd" + 0.250*"title" + 0.250*"question"
# Topic 1: 0.250*"question" + 0.250*"title" + 0.250*"articlehttpschatopenaicomsharebfdccfbdd" + 0.250*"answer"
# Topic 2: question, title, articlehttpschatopenaicomsharebfdccfbdd, answer
# Topic 1: answer, articlehttpschatopenaicomsharebfdccfbdd, title, question
# Top Topics for https://news.ycombinator.com/item?id=36445085: Topic 2: question, title, articlehttpschatopenaicomsharebfdccfbdd, answer; Topic 1: answer, articlehttpschatopenaicomsharebfdccfbdd, title, question
# Processing URL: https://news.ycombinator.com/item?id=36434885 with 124 comments.
# Topic 0: 0.018*"reddit" + 0.005*"dont" + 0.005*"community" + 0.005*"think" + 0.005*"users"
# Topic 1: 0.020*"reddit" + 0.007*"would" + 0.007*"users" + 0.006*"people" + 0.005*"even"
# Topic 1: reddit, dont, community, think, users
# Top Topics for https://news.ycombinator.com/item?id=36434885: Topic 1: reddit, dont, community, think, users
# Processing URL: https://news.ycombinator.com/item?id=36421315 with 126 comments.
# Topic 0: 0.012*"people" + 0.009*"dont" + 0.008*"map" + 0.008*"like" + 0.007*"countries"
# Topic 1: 0.016*"projection" + 0.012*"countries" + 0.012*"mercator" + 0.011*"maps" + 0.010*"map"
# Topic 1: people, dont, map, like, countries
# Topic 2: projection, countries, mercator, maps, map
# Top Topics for https://news.ycombinator.com/item?id=36421315: Topic 1: people, dont, map, like, countries; Topic 2: projection, countries, mercator, maps, map
# No comments available for URL: https://news.ycombinator.com/item?id=36427347
# No comments available for URL: https://news.ycombinator.com/item?id=36427234
# Processing URL: https://news.ycombinator.com/item?id=36413260 with 1 comments.
# Topic 0: 0.503*"httpschatopenaicomsharefddcbaea" + 0.497*"stunning"
# Topic 1: 0.502*"stunning" + 0.498*"httpschatopenaicomsharefddcbaea"
# Topic 2: stunning, httpschatopenaicomsharefddcbaea
# Topic 1: httpschatopenaicomsharefddcbaea, stunning
# ...
# Topic 2: ai, extension, extensions, user, browser
# Top Topics for https://news.ycombinator.com/item?id=36243951: Topic 1: intelligence, ai, people, intelligent, dont; Topic 2: ai, extension, extensions, user, browser
# No comments available for URL: https://news.ycombinator.com/item?id=36244823
# Processing URL: https://news.ycombinator.com/item?id=36239936 with 15 comments.
# Topic 0: 0.035*"car" + 0.032*"per" + 0.027*"year" + 0.021*"cost" + 0.019*"day"
# Topic 1: 0.016*"car" + 0.014*"bus" + 0.013*"go" + 0.013*"public" + 0.011*"every"
# Topic 1: car, per, year, cost, day
# Top Topics for https://news.ycombinator.com/item?id=36239936: Topic 1: car, per, year, cost, day
# Processing URL: https://news.ycombinator.com/item?id=36218960 with 7 comments.
# Topic 0: 0.023*"server" + 0.016*"sends" + 0.016*"menuthe" + 0.016*"items" + 0.010*"rest"
# Topic 1: 0.019*"data" + 0.017*"frontend" + 0.013*"display" + 0.013*"typename" + 0.013*"server"
# Topic 2: data, frontend, display, typename, server
# Topic 1: server, sends, menuthe, items, rest
# Top Topics for https://news.ycombinator.com/item?id=36218960: Topic 2: data, frontend, display, typename, server; Topic 1: server, sends, menuthe, items, rest
# Processing URL: https://news.ycombinator.com/item?id=36217302 with 4 comments.
# Topic 0: 0.046*"slambda" + 0.033*"lambda" + 0.033*"alambda" + 0.033*"xlambda" + 0.033*"plambda"
# Topic 1: 0.044*"limit" + 0.044*"running" + 0.044*"tip" + 0.044*"pythons" + 0.044*"recursion"
# Topic 1: slambda, lambda, alambda, xlambda, plambda
# Topic 2: limit, running, tip, pythons, recursion
# Top Topics for https://news.ycombinator.com/item?id=36217302: Topic 1: slambda, lambda, alambda, xlambda, plambda; Topic 2: limit, running, tip, pythons, recursion
# No comments available for URL: https://news.ycombinator.com/item?id=36217780
# Processing URL: https://news.ycombinator.com/item?id=36212865 with 17 comments.
# Topic 0: 0.028*"braiding" + 0.016*"topological" + 0.010*"around" + 0.010*"black" + 0.010*"start"
# Topic 1: 0.023*"quantum" + 0.013*"theory" + 0.011*"information" + 0.011*"surface" + 0.008*"local"
# Topic 1: braiding, topological, around, black, start
# Top Topics for https://news.ycombinator.com/item?id=36212865: Topic 1: braiding, topological, around, black, start
# Processing URL: https://news.ycombinator.com/item?id=36197291 with 104 comments.
# Topic 0: 0.007*"would" + 0.006*"grandma" + 0.006*"example" + 0.006*"english" + 0.005*"gpt"
# Topic 1: 0.010*"writing" + 0.008*"people" + 0.007*"gpt" + 0.007*"use" + 0.006*"gpts"
# Topic 2: writing, people, gpt, use, gpts
# Topic 1: would, grandma, example, english, gpt
# Top Topics for https://news.ycombinator.com/item?id=36197291: Topic 2: writing, people, gpt, use, gpts; Topic 1: would, grandma, example, english, gpt
# Processing URL: https://news.ycombinator.com/item?id=36178263 with 1 comments.
# Topic 0: 0.069*"ask" + 0.069*"questions" + 0.041*"wantyou" + 0.041*"chatgpt" + 0.041*"trying"
# Topic 1: 0.044*"questions" + 0.044*"ask" + 0.044*"give" + 0.044*"something" + 0.043*"im"
# Topic 1: ask, questions, wantyou, chatgpt, trying
# Topic 2: questions, ask, give, something, im
# Top Topics for https://news.ycombinator.com/item?id=36178263: Topic 1: ask, questions, wantyou, chatgpt, trying; Topic 2: questions, ask, give, something, im
# Processing URL: https://news.ycombinator.com/item?id=36184315 with 36 comments.
# Topic 0: 0.009*"would" + 0.009*"reasoning" + 0.008*"skills" + 0.008*"gpt" + 0.007*"llms"
# Topic 1: 0.010*"know" + 0.010*"think" + 0.008*"one" + 0.008*"dont" + 0.007*"people"
# Topic 1: would, reasoning, skills, gpt, llms
# Top Topics for https://news.ycombinator.com/item?id=36184315: Topic 1: would, reasoning, skills, gpt, llms
# No comments available for URL: https://news.ycombinator.com/item?id=36183551
# Processing URL: https://news.ycombinator.com/item?id=36182700 with 1 comments.
# Topic 0: 0.502*"generated" + 0.498*"chatgpthttpschatopenaicomshareeccaadab"
# Topic 1: 0.504*"chatgpthttpschatopenaicomshareeccaadab" + 0.496*"generated"
# Topic 1: generated, chatgpthttpschatopenaicomshareeccaadab
# Topic 2: chatgpthttpschatopenaicomshareeccaadab, generated
# Top Topics for https://news.ycombinator.com/item?id=36182700: Topic 1: generated, chatgpthttpschatopenaicomshareeccaadab; Topic 2: chatgpthttpschatopenaicomshareeccaadab, generated
# No comments available for URL: https://news.ycombinator.com/item?id=36182546
# Processing URL: https://news.ycombinator.com/item?id=36179333 with 7 comments.
# Topic 0: 0.017*"article" + 0.017*"need" + 0.017*"maybe" + 0.017*"like" + 0.010*"interesting"
# Topic 1: 0.022*"yeah" + 0.022*"effort" + 0.022*"idea" + 0.014*"also" + 0.014*"chatgpt"
# Topic 1: article, need, maybe, like, interesting
# Top Topics for https://news.ycombinator.com/item?id=36179333: Topic 1: article, need, maybe, like, interesting
# No comments available for URL: https://news.ycombinator.com/item?id=36181100
# Processing URL: https://news.ycombinator.com/item?id=36178342 with 3 comments.
# Topic 0: 0.029*"going" + 0.021*"chatgpt" + 0.021*"ai" + 0.021*"wrong" + 0.021*"way"
# Topic 1: 0.043*"citations" + 0.018*"recommended" + 0.018*"statement" + 0.018*"cause" + 0.018*"real"
# Topic 1: going, chatgpt, ai, wrong, way
# Topic 2: citations, recommended, statement, cause, real
# Top Topics for https://news.ycombinator.com/item?id=36178342: Topic 1: going, chatgpt, ai, wrong, way; Topic 2: citations, recommended, statement, cause, real
# No comments available for URL: https://news.ycombinator.com/item?id=36178465
# No comments available for URL: https://news.ycombinator.com/item?id=36177521
# Processing URL: https://news.ycombinator.com/item?id=36177354 with 1 comments.
# Topic 0: 0.037*"seems" + 0.022*"solution" + 0.022*"application" + 0.022*"httpschatopenaicomshareafbceacfaecdeaccan" + 0.022*"else"
# Topic 1: 0.023*"seems" + 0.023*"loop" + 0.023*"oauth" + 0.023*"lately" + 0.023*"issuing"
# Topic 1: seems, solution, application, httpschatopenaicomshareafbceacfaecdeaccan, else
# Topic 2: seems, loop, oauth, lately, issuing
# Top Topics for https://news.ycombinator.com/item?id=36177354: Topic 1: seems, solution, application, httpschatopenaicomshareafbceacfaecdeaccan, else; Topic 2: seems, loop, oauth, lately, issuing
# No comments available for URL: https://news.ycombinator.com/item?id=36175912
# No comments available for URL: https://news.ycombinator.com/item?id=36173630
# Processing URL: https://news.ycombinator.com/item?id=36158702 with 74 comments.
# Topic 0: 0.010*"chatgpt" + 0.008*"people" + 0.007*"think" + 0.007*"llms" + 0.006*"hype"
# Topic 1: 0.009*"code" + 0.007*"ai" + 0.006*"like" + 0.005*"dont" + 0.005*"generative"
# Topic 1: chatgpt, people, think, llms, hype
# Topic 2: code, ai, like, dont, generative
# Top Topics for https://news.ycombinator.com/item?id=36158702: Topic 1: chatgpt, people, think, llms, hype; Topic 2: code, ai, like, dont, generative
# Processing URL: https://news.ycombinator.com/item?id=36155267 with 36 comments.
# Topic 0: 0.037*"version" + 0.010*"dont" + 0.009*"look" + 0.008*"good" + 0.008*"even"
# Topic 1: 0.016*"code" + 0.010*"coding" + 0.008*"python" + 0.007*"gpt" + 0.007*"got"
# Topic 1: version, dont, look, good, even
# Topic 2: code, coding, python, gpt, got
# Top Topics for https://news.ycombinator.com/item?id=36155267: Topic 1: version, dont, look, good, even; Topic 2: code, coding, python, gpt, got
# Processing URL: https://news.ycombinator.com/item?id=36155583 with 2 comments.
# Topic 0: 0.071*"jiggybase" + 0.043*"make" + 0.043*"uploaded" + 0.043*"collection" + 0.043*"gpt"
# Topic 1: 0.058*"trademark" + 0.035*"experience" + 0.035*"us" + 0.035*"feature" + 0.035*"characteristic"
# Topic 2: trademark, experience, us, feature, characteristic
# Topic 1: jiggybase, make, uploaded, collection, gpt
# Top Topics for https://news.ycombinator.com/item?id=36155583: Topic 2: trademark, experience, us, feature, characteristic; Topic 1: jiggybase, make, uploaded, collection, gpt
# Processing URL: https://news.ycombinator.com/item?id=36152510 with 49 comments.
# Topic 0: 0.015*"skilled" + 0.014*"workers" + 0.010*"ai" + 0.009*"productivity" + 0.008*"much"
# Topic 1: 0.008*"would" + 0.007*"going" + 0.006*"like" + 0.006*"dont" + 0.006*"productivity"
# Topic 1: skilled, workers, ai, productivity, much
# Topic 2: would, going, like, dont, productivity
# Top Topics for https://news.ycombinator.com/item?id=36152510: Topic 1: skilled, workers, ai, productivity, much; Topic 2: would, going, like, dont, productivity
# Processing URL: https://news.ycombinator.com/item?id=36145823 with 10 comments.
# Topic 0: 0.016*"like" + 0.013*"one" + 0.013*"negative" + 0.008*"self" + 0.008*"cognitive"
# Topic 1: 0.014*"angry" + 0.014*"really" + 0.011*"people" + 0.011*"little" + 0.009*"simply"
# Topic 1: like, one, negative, self, cognitive
# Top Topics for https://news.ycombinator.com/item?id=36145823: Topic 1: like, one, negative, self, cognitive
# Processing URL: https://news.ycombinator.com/item?id=36147332 with 1 comments.
# Topic 0: 0.007*"midjourney" + 0.007*"scene" + 0.006*"comic" + 0.006*"get" + 0.006*"chatgpt"
# Topic 1: 0.026*"midjourney" + 0.019*"scene" + 0.016*"generate" + 0.012*"person" + 0.012*"couldnt"
# Topic 1: midjourney, scene, comic, get, chatgpt
# Top Topics for https://news.ycombinator.com/item?id=36147332: Topic 1: midjourney, scene, comic, get, chatgpt
# Processing URL: https://news.ycombinator.com/item?id=36144241 with 40 comments.
# Topic 0: 0.017*"copyright" + 0.009*"copyrighted" + 0.008*"llm" + 0.008*"copies" + 0.008*"works"
# Topic 1: 0.010*"see" + 0.009*"copyright" + 0.009*"book" + 0.008*"harry" + 0.008*"potter"
# Topic 2: see, copyright, book, harry, potter
# Topic 1: copyright, copyrighted, llm, copies, works
# Top Topics for https://news.ycombinator.com/item?id=36144241: Topic 2: see, copyright, book, harry, potter; Topic 1: copyright, copyrighted, llm, copies, works
# Processing URL: https://news.ycombinator.com/item?id=36134249 with 306 comments.
# Topic 0: 0.007*"people" + 0.007*"would" + 0.005*"like" + 0.005*"think" + 0.005*"dont"
# Topic 1: 0.007*"like" + 0.006*"dont" + 0.006*"one" + 0.005*"people" + 0.004*"model"
# Topic 1: people, would, like, think, dont
# Topic 2: like, dont, one, people, model
# Top Topics for https://news.ycombinator.com/item?id=36134249: Topic 1: people, would, like, think, dont; Topic 2: like, dont, one, people, model
# Processing URL: https://news.ycombinator.com/item?id=36131450 with 11 comments.
# Topic 0: 0.026*"latin" + 0.024*"english" + 0.021*"french" + 0.014*"pro" + 0.014*"phrase"
# Topic 1: 0.020*"people" + 0.015*"training" + 0.015*"makes" + 0.015*"noticed" + 0.011*"lot"
# Topic 1: latin, english, french, pro, phrase
# Topic 2: people, training, makes, noticed, lot
# Top Topics for https://news.ycombinator.com/item?id=36131450: Topic 1: latin, english, french, pro, phrase; Topic 2: people, training, makes, noticed, lot
# Processing URL: https://news.ycombinator.com/item?id=36130354 with 83 comments.
# Topic 0: 0.012*"chatgpt" + 0.011*"answer" + 0.009*"questions" + 0.009*"like" + 0.009*"dont"
# Topic 1: 0.014*"gpt" + 0.011*"know" + 0.009*"chatgpt" + 0.008*"dont" + 0.007*"yes"
# Topic 1: chatgpt, answer, questions, like, dont
# Top Topics for https://news.ycombinator.com/item?id=36130354: Topic 1: chatgpt, answer, questions, like, dont
# Processing URL: https://news.ycombinator.com/item?id=36123082 with 56 comments.
# Topic 0: 0.010*"dont" + 0.007*"intelligence" + 0.007*"superintelligence" + 0.007*"ai" + 0.007*"humans"
# Topic 1: 0.010*"ai" + 0.009*"would" + 0.009*"superintelligence" + 0.009*"power" + 0.008*"virus"
# Topic 1: dont, intelligence, superintelligence, ai, humans
# Top Topics for https://news.ycombinator.com/item?id=36123082: Topic 1: dont, intelligence, superintelligence, ai, humans
# Processing URL: https://news.ycombinator.com/item?id=36122558 with 1 comments.
# Topic 0: 0.038*"llm" + 0.038*"chatgpt" + 0.023*"solution" + 0.023*"architecture" + 0.023*"doesnt"
# Topic 1: 0.024*"chatgpt" + 0.024*"llm" + 0.024*"similar" + 0.024*"gohttpschatopenaicomshareebbdeebffc" + 0.024*"see"
# Topic 1: llm, chatgpt, solution, architecture, doesnt
# Topic 2: chatgpt, llm, similar, gohttpschatopenaicomshareebbdeebffc, see
# Top Topics for https://news.ycombinator.com/item?id=36122558: Topic 1: llm, chatgpt, solution, architecture, doesnt; Topic 2: chatgpt, llm, similar, gohttpschatopenaicomshareebbdeebffc, see
# Processing URL: https://news.ycombinator.com/item?id=36111878 with 18 comments.
# Topic 0: 0.019*"related" + 0.017*"good" + 0.013*"answer" + 0.013*"gpt" + 0.011*"great"
# Topic 1: 0.013*"even" + 0.012*"tools" + 0.012*"used" + 0.012*"list" + 0.012*"find"
# Topic 2: even, tools, used, list, find
# Topic 1: related, good, answer, gpt, great
# Top Topics for https://news.ycombinator.com/item?id=36111878: Topic 2: even, tools, used, list, find; Topic 1: related, good, answer, gpt, great
# No comments available for URL: https://news.ycombinator.com/item?id=36115457
# Processing URL: https://news.ycombinator.com/item?id=36113308 with 1 comments.
# Topic 0: 0.019*"small" + 0.019*"share" + 0.019*"see" + 0.019*"heres" + 0.019*"pitch"
# Topic 1: 0.043*"see" + 0.030*"share" + 0.030*"small" + 0.018*"chatsi" + 0.018*"game"
# Topic 2: see, share, small, chatsi, game
# Topic 1: small, share, see, heres, pitch
# Top Topics for https://news.ycombinator.com/item?id=36113308: Topic 2: see, share, small, chatsi, game; Topic 1: small, share, see, heres, pitch
# No comments available for URL: https://news.ycombinator.com/item?id=36111917
# No comments available for URL: https://news.ycombinator.com/item?id=36111140
# No comments available for URL: https://news.ycombinator.com/item?id=36109423
# Processing URL: https://news.ycombinator.com/item?id=36101429 with 31 comments.
# Topic 0: 0.016*"llms" + 0.008*"making" + 0.008*"testing" + 0.008*"classifier" + 0.007*"prompt"
# Topic 1: 0.015*"print" + 0.015*"function" + 0.013*"len" + 0.010*"functions" + 0.010*"main"
# Topic 2: print, function, len, functions, main
# Topic 1: llms, making, testing, classifier, prompt
# Top Topics for https://news.ycombinator.com/item?id=36101429: Topic 2: print, function, len, functions, main; Topic 1: llms, making, testing, classifier, prompt
# Processing URL: https://news.ycombinator.com/item?id=36098511 with 1 comments.
# Topic 0: 0.053*"code" + 0.041*"files" + 0.041*"python" + 0.029*"information" + 0.029*"finished"
# Topic 1: 0.022*"code" + 0.021*"python" + 0.021*"working" + 0.021*"files" + 0.021*"gpt"
# Topic 1: code, files, python, information, finished
# Top Topics for https://news.ycombinator.com/item?id=36098511: Topic 1: code, files, python, information, finished
# Processing URL: https://news.ycombinator.com/item?id=36097321 with 11 comments.
# Topic 0: 0.018*"function" + 0.015*"go" + 0.015*"runtime" + 0.014*"goroutines" + 0.013*"would"
# Topic 1: 0.033*"runtime" + 0.016*"library" + 0.011*"libraries" + 0.011*"run" + 0.011*"windows"
# Topic 2: runtime, library, libraries, run, windows
# Topic 1: function, go, runtime, goroutines, would
# Top Topics for https://news.ycombinator.com/item?id=36097321: Topic 2: runtime, library, libraries, run, windows; Topic 1: function, go, runtime, goroutines, would
# Processing URL: https://news.ycombinator.com/item?id=36097900 with 4 comments.
# Topic 0: 0.030*"case" + 0.024*"chatgpt" + 0.024*"might" + 0.019*"court" + 0.019*"generated"
# Topic 1: 0.034*"loop" + 0.020*"output" + 0.020*"well" + 0.020*"solve" + 0.020*"problem"
# Topic 1: case, chatgpt, might, court, generated
# Top Topics for https://news.ycombinator.com/item?id=36097900: Topic 1: case, chatgpt, might, court, generated
# No comments available for URL: https://news.ycombinator.com/item?id=36092767
# Processing URL: https://news.ycombinator.com/item?id=36091388 with 73 comments.
# Topic 0: 0.006*"saudi" + 0.005*"chatgpt" + 0.005*"context" + 0.004*"would" + 0.004*"openai"
# Topic 1: 0.006*"creative" + 0.006*"consciousness" + 0.006*"cosmic" + 0.005*"model" + 0.005*"like"
# Topic 1: saudi, chatgpt, context, would, openai
# Top Topics for https://news.ycombinator.com/item?id=36091388: Topic 1: saudi, chatgpt, context, would, openai
# No comments available for URL: https://news.ycombinator.com/item?id=36091892
# Output written to hacker_news_with_chatopenai_topics.csv
